# %% [markdown]
# Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following questions
# Note - 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
# Insights to be drawn -
# * Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# * Get all TESLA cars with the model year, and model type made in Bothell City.
# * Get all the cars that have an electric range of more than 100, and were made after 2015
# * Draw plots to show the distribution between city and electric vehicle type

# %%
import csv
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset/Electric_Vehicle_Population_Data.csv")

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
df.shape
# Out:
# (130443, 17)

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility']!="Clean Alternative Fuel Vehicle Eligible"][['Electric Vehicle Type','Make','Model']]
# Out:
#                          Electric Vehicle Type    Make    Model
# 6       Plug-in Hybrid Electric Vehicle (PHEV)    FORD   FUSION
# 7       Plug-in Hybrid Electric Vehicle (PHEV)    AUDI     Q5 E
# 8       Plug-in Hybrid Electric Vehicle (PHEV)    FORD    C-MAX
# 11              Battery Electric Vehicle (BEV)   TESLA  MODEL Y
# 14      Plug-in Hybrid Electric Vehicle (PHEV)    FORD    C-MAX
# ...                                        ...     ...      ...
# 130437  Plug-in Hybrid Electric Vehicle (PHEV)     BMW     530E
# 130438          Battery Electric Vehicle (BEV)   TESLA  MODEL Y
# 130439          Battery Electric Vehicle (BEV)  NISSAN     LEAF
# 130440          Battery Electric Vehicle (BEV)   TESLA  MODEL Y
# 130442          Battery Electric Vehicle (BEV)   TESLA  MODEL 3
#
# [69892 rows x 3 columns]

# %%
# Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
df.head()
df[(df['Make']== 'TESLA') & (df['City'] == 'Bothell')].head()
# Out:
#      VIN (1-10)     County     City State  Postal Code  Model Year   Make  \
# 39   5YJ3E1EA6L  Snohomish  Bothell    WA      98012.0        2020  TESLA
# 217  5YJ3E1EB9N       King  Bothell    WA      98011.0        2022  TESLA
# 218  7SAYGDEEXN  Snohomish  Bothell    WA      98012.0        2022  TESLA
# 222  5YJ3E1EB6J       King  Bothell    WA      98011.0        2018  TESLA
# 292  5YJXCBE40H       King  Bothell    WA      98011.0        2017  TESLA
#
#        Model           Electric Vehicle Type  \
# 39   MODEL 3  Battery Electric Vehicle (BEV)
# 217  MODEL 3  Battery Electric Vehicle (BEV)
# 218  MODEL Y  Battery Electric Vehicle (BEV)
# 222  MODEL 3  Battery Electric Vehicle (BEV)
# 292  MODEL X  Battery Electric Vehicle (BEV)
#
#      Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 39             Clean Alternative Fuel Vehicle Eligible             266
# 217  Eligibility unknown as battery range has not b...               0
# ...

# %%
# Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df.head()
df[(df['Electric Range']> 100) & (df['Model Year']>2015)].head()
# Out:
#     VIN (1-10)    County     City State  Postal Code  Model Year   Make  \
# 0   5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018  TESLA
# 2   5YJ3E1EB0K      King  Seattle    WA      98199.0        2019  TESLA
# 4   5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017  TESLA
# 12  5YJ3E1EC7L  Thurston    Lacey    WA      98503.0        2020  TESLA
# 13  5YJ3E1EB2L  Thurston  Olympia    WA      98516.0        2020  TESLA
#
#       Model           Electric Vehicle Type  \
# 0   MODEL X  Battery Electric Vehicle (BEV)
# 2   MODEL 3  Battery Electric Vehicle (BEV)
# 4   MODEL S  Battery Electric Vehicle (BEV)
# 12  MODEL 3  Battery Electric Vehicle (BEV)
# 13  MODEL 3  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             238
# 2            Clean Alternative Fuel Vehicle Eligible             220
# ...

# %%
# Draw plots to show the distribution between city and electric vehicle type

# %%
count_data = df.groupby(['City', 'Electric Vehicle Type']).size().reset_index(name='Count')

# Plot the bar plot
plt.figure(figsize=(20,6))
sns.barplot(x='City', y='Count', hue='Electric Vehicle Type', data=count_data)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Distribution of Electric Vehicle Types in Cities')
plt.legend(title='Electric Vehicle Type')
plt.show()
